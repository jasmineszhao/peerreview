# %% [markdown]
# Notes:
#
# raw data file: had to manually fix the formatting (deleting the top few rows and replacing file with my own)
# all paths were absolute paths, i had to manually edit them
# there were no comments whatsoever, unclear what was supposed to do what
# a lot of it references hw 4, but i dont know what their file structure is for hw 4.
